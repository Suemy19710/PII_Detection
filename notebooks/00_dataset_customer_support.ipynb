# %%
# %pip install datasets
# Out:
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import load_dataset

ds = load_dataset("MohammadOthman/mo-customer-support-tweets-945k")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\nguye\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nguye\.cache\huggingface\hub\datasets--MohammadOthman--mo-customer-support-tweets-945k. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
print(type(ds))
# Out:
# <class 'datasets.dataset_dict.DatasetDict'>

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['output', 'input'],
#         num_rows: 945278
#     })
# })

# %%
df = ds["train"].to_pandas()

# %%
df.head()
# Out:
#                                               output  \
# 0  I would love the chance to review the account ...
# 1  H there! we would definitely like to work with...
# 2  We understand your concerns and we would like ...
# 3  This is saddening to hear. Please shoot us a D...
# 4  Please send me a private message so that I can...
#
#                                                input
# 0                      is the worst customer service
# 1  y’all lie about your “great” connection. 5 bar...
# 2          Since I signed up with you....Since day 1
# 3  You gonna magically change your connectivity f...
# 4  whenever I contact customer support, they tell...

# %%
print(df.shape)
# Out:
# (945278, 2)

# %%
df.to_csv('customer_support.csv', index=False)
print("Successfully save csv!")
# Out:
# Successfully save csv!

# %%
import pandas as pd
df_test = pd.read_csv('../data/pii_test_data.csv')
# df_test.head()

df_test[["user_input", "assistant_output"]].head()
df_test[["user_input", "assistant_output"]].to_csv('pii_test_data(2).csv', index=False)
print("Successfully save csv!")
# Out:
# Successfully save csv!

# %%
df_test.head(20)
# Out:
#    conversation_id            timestamp  \
# 0         conv_001  2024-11-15 09:23:45
# 1         conv_002  2024-11-15 10:14:22
# 2         conv_003  2024-11-15 11:05:33
# 3         conv_004  2024-11-15 12:45:18
# 4         conv_005  2024-11-15 13:22:09
# 5         conv_006  2024-11-15 14:33:51
# 6         conv_007  2024-11-15 15:18:44
# 7         conv_008  2024-11-15 16:07:29
# 8         conv_009  2024-11-15 17:25:13
# 9         conv_010  2024-11-15 18:42:37
# 10        conv_011  2024-11-16 08:15:22
# 11        conv_012  2024-11-16 09:33:48
# 12        conv_013  2024-11-16 10:48:15
# 13        conv_014  2024-11-16 11:52:39
# 14        conv_015  2024-11-16 13:14:27
# 15        conv_016  2024-11-16 14:29:55
# 16        conv_017  2024-11-16 15:41:18
# 17        conv_018  2024-11-16 16:55:42
# 18        conv_019  2024-11-16 17:22:09
# 19        conv_020  2024-11-16 18:47:33
#
#                                            user_input  \
# ...
